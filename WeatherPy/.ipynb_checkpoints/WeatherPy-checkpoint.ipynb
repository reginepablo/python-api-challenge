# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
import json
import requests
from scipy.stats import linregress

#Import api key
from api_keys import weather_api_key

#Import Citipy
from citipy import citipy

output = "output_data/cities.csv"

latitude = (-90, 90)
longitude = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

print(len(cities))
# Out:
# 641

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + weather_api_key + '&units=imperial' + "&q=" + city


city_name = []
cloudiness = []
country = []
date = []
lng = []
lat = []
humidity = []
max_temp = []
windspeed = []
record = 0


for city in cities:
    record += 1
    url = "http://api.openweathermap.org/data/2.5/weather?"
    query_url = url + "appid=" + weather_api_key + '&units=imperial' + "&q=" + city
    response = requests.get(query_url)
    city_json = response.json()
    if (str(response) == '<Response [200]>'):
        print(f'Processing Record {record}: {city}')
        city_name.append(city_json['name'])
        country.append(city_json['sys']['country'])
        cloudiness.append(city_json['clouds']['all'])
        date.append(city_json['dt'])
        humidity.append(city_json['main']['humidity'])
        lat.append(city_json['coord']['lat'])
        lng.append(city_json['coord']['lon'])
        max_temp.append(city_json['main']['temp_max'])
        windspeed.append(city_json['wind']['speed'])
    else:
        print('City not found. Skipping...')

    time.sleep(1)

w_dict = {'City':city_name,
                'Country':country,
                'Date':date,
                'Latitude':lat,
                'Longitude':lng,
                'Cloudiness (%)':cloudiness,
                'Humidity (%)':humidity,
                'Max Temp (F)':max_temp,
                'Wind Speed (mph)':windspeed}

weather_df = pd.DataFrame(w_dict)
# Out:
# Processing Record 1: hithadhoo
# City not found. Skipping...
# Processing Record 3: san quintin
# Processing Record 4: palasbari
# Processing Record 5: hobart
# City not found. Skipping...
# Processing Record 7: soe
# Processing Record 8: krasnoselkup
# Processing Record 9: zunyi
# Processing Record 10: mataura
# Processing Record 11: rikitea
# Processing Record 12: cangucu
# Processing Record 13: rurrenabaque
# Processing Record 14: quimper
# Processing Record 15: bredasdorp
# City not found. Skipping...
# Processing Record 17: phalombe
# Processing Record 18: rio grande
# Processing Record 19: dalton
# Processing Record 20: tuatapere
# Processing Record 21: ribeira grande
# Processing Record 22: albany
# Processing Record 23: marigot
# Processing Record 24: hasaki
# Processing Record 25: kysyl-syr
# City not found. Skipping...
# Processing Record 27: nanortalik
# Processing Record 28: upernavik
# Processing Record 29: begun
# Processing Record 30: jamestown
# Processing Record 31: dikson
# Processing Record 32: avarua
# Processing Record 33: eyl
# Processing Record 34: tiksi
# Processing Record 35: tornio
# Processing Record 36: ucluelet
# Processing Record 37: east london
# Processing Record 38: verkhnetulomskiy
# Processing Record 39: pahrump
# Processing Record 40: kapit
# Processing Record 41: bayeux
# City not found. Skipping...
# Processing Record 43: ushuaia
# Processing Record 44: sitka
# Processing Record 45: cherskiy
# Processing Record 46: merauke
# Processing Record 47: aleksandrov gay
# Processing Record 48: butaritari
# Processing Record 49: shimanovsk
# Processing Record 50: katsuura
# Processing Record 51: port alfred
# Processing Record 52: hilo
# Processing Record 53: kemijarvi
# Processing Record 54: cockburn town
# City not found. Skipping...
# Processing Record 56: claveria
# Processing Record 57: barrow
# Processing Record 58: iqaluit
# Processing Record 59: kirakira
# Processing Record 60: perambalur
# Processing Record 61: ouallam
# City not found. Skipping...
# Processing Record 63: pangnirtung
# Processing Record 64: puerto ayora
# Processing Record 65: bluff
# Processing Record 66: yarada
# Processing Record 67: atuona
# Processing Record 68: poum
# Processing Record 69: saint-philippe
# Processing Record 70: guasdualito
# Processing Record 71: vaini
# Processing Record 72: abadan
# Processing Record 73: tiarei
# Processing Record 74: ishigaki
# Processing Record 75: busselton
# Processing Record 76: tasiilaq
# Processing Record 77: elblag
# Processing Record 78: new norfolk
# Processing Record 79: nouadhibou
# Processing Record 80: chokurdakh
# Processing Record 81: pirovskoye
# Processing Record 82: padang
# Processing Record 83: roma
# Processing Record 84: moron
# Processing Record 85: hami
# Processing Record 86: kapaa
# Processing Record 87: honiara
# Processing Record 88: victoria
# Processing Record 89: praia
# Processing Record 90: itarema
# Processing Record 91: ilulissat
# Processing Record 92: port elizabeth
# Processing Record 93: tamiahua
# City not found. Skipping...
# Processing Record 95: la macarena
# Processing Record 96: arraial do cabo
# Processing Record 97: chuy
# Processing Record 98: port hardy
# Processing Record 99: garden city
# City not found. Skipping...
# Processing Record 101: nizhnevartovsk
# Processing Record 102: ust-ordynskiy
# Processing Record 103: willmar
# Processing Record 104: waipawa
# Processing Record 105: mikhaylovka
# Processing Record 106: kroya
# Processing Record 107: carnarvon
# Processing Record 108: luena
# Processing Record 109: khatanga
# Processing Record 110: kodiak
# Processing Record 111: doka
# Processing Record 112: boguchany
# Processing Record 113: nikolskoye
# Processing Record 114: naze
# Processing Record 115: solnechnyy
# Processing Record 116: matucana
# Processing Record 117: rivera
# Processing Record 118: tuktoyaktuk
# Processing Record 119: bethel
# Processing Record 120: qaanaaq
# Processing Record 121: boueni
# Processing Record 122: sioux city
# Processing Record 123: dongsheng
# Processing Record 124: faya
# Processing Record 125: zhigansk
# Processing Record 126: torrevieja
# Processing Record 127: cidreira
# Processing Record 128: omsukchan
# Processing Record 129: jiayuguan
# Processing Record 130: verkhnevilyuysk
# Processing Record 131: faanui
# Processing Record 132: joshimath
# Processing Record 133: northam
# City not found. Skipping...
# Processing Record 135: oga
# Processing Record 136: norman wells
# Processing Record 137: sile
# Processing Record 138: geraldton
# Processing Record 139: bengkulu
# Processing Record 140: la ronge
# Processing Record 141: aklavik
# Processing Record 142: mayna
# Processing Record 143: pacific grove
# Processing Record 144: camacha
# City not found. Skipping...
# Processing Record 146: ponferrada
# Processing Record 147: punta arenas
# Processing Record 148: zyryanka
# Processing Record 149: mahebourg
# Processing Record 150: tommot
# Processing Record 151: almaznyy
# Processing Record 152: saiha
# Processing Record 153: severo-kurilsk
# Processing Record 154: sur
# Processing Record 155: umm kaddadah
# Processing Record 156: vila
# City not found. Skipping...
# Processing Record 158: sweetwater
# Processing Record 159: russell
# Processing Record 160: barabinsk
# Processing Record 161: sioux lookout
# Processing Record 162: salalah
# Processing Record 163: kolda
# Processing Record 164: cape town
# City not found. Skipping...
# Processing Record 166: kavieng
# Processing Record 167: vila velha
# Processing Record 168: garmsar
# Processing Record 169: kawambwa
# Processing Record 170: hermanus
# Processing Record 171: palafrugell
# Processing Record 172: pisco
# Processing Record 173: belmonte
# City not found. Skipping...
# Processing Record 175: petersburg
# Processing Record 176: suratgarh
# Processing Record 177: kargil
# Processing Record 178: petushki
# Processing Record 179: moissala
# Processing Record 180: zakamensk
# Processing Record 181: kosa
# Processing Record 182: labuhan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 185: calvinia
# Processing Record 186: petauke
# Processing Record 187: shenjiamen
# Processing Record 188: maradi
# Processing Record 189: lavrentiya
# Processing Record 190: tual
# Processing Record 191: bastia
# Processing Record 192: egvekinot
# Processing Record 193: nouakchott
# Processing Record 194: cayenne
# Processing Record 195: mount isa
# Processing Record 196: maebaru
# City not found. Skipping...
# Processing Record 198: mwinilunga
# City not found. Skipping...
# Processing Record 200: vandra
# Processing Record 201: nsanje
# Processing Record 202: sorong
# Processing Record 203: alofi
# Processing Record 204: ahipara
# Processing Record 205: yichun
# Processing Record 206: castro
# Processing Record 207: gornopravdinsk
# Processing Record 208: gossaigaon
# Processing Record 209: kautokeino
# City not found. Skipping...
# Processing Record 211: kungurtug
# Processing Record 212: millau
# Processing Record 213: coquimbo
# Processing Record 214: bambous virieux
# Processing Record 215: grand-santi
# Processing Record 216: kuusamo
# Processing Record 217: obo
# Processing Record 218: vallenar
# Processing Record 219: kherson
# Processing Record 220: georgetown
# Processing Record 221: van
# Processing Record 222: weiser
# Processing Record 223: saldanha
# Processing Record 224: huarmey
# Processing Record 225: omboue
# Processing Record 226: lebu
# Processing Record 227: airai
# Processing Record 228: coihaique
# Processing Record 229: ternate
# Processing Record 230: winnemucca
# Processing Record 231: spornoye
# Processing Record 232: mana
# Processing Record 233: klaksvik
# Processing Record 234: llanelli
# Processing Record 235: honningsvag
# Processing Record 236: pinotepa nacional
# Processing Record 237: havoysund
# Processing Record 238: lagoa
# Processing Record 239: road town
# Processing Record 240: husavik
# Processing Record 241: narsaq
# Processing Record 242: hollola
# Processing Record 243: saskylakh
# Processing Record 244: lisakovsk
# Processing Record 245: grindavik
# City not found. Skipping...
# Processing Record 247: coffs harbour
# Processing Record 248: cabo san lucas
# Processing Record 249: arona
# Processing Record 250: kondinskoye
# Processing Record 251: tevaitoa
# City not found. Skipping...
# Processing Record 253: melfi
# Processing Record 254: saint-joseph
# Processing Record 255: pevek
# Processing Record 256: nantucket
# Processing Record 257: pitiquito
# Processing Record 258: dublin
# Processing Record 259: taoudenni
# Processing Record 260: catuday
# Processing Record 261: lasa
# City not found. Skipping...
# Processing Record 263: kachiry
# Processing Record 264: challapata
# City not found. Skipping...
# Processing Record 266: san patricio
# Processing Record 267: kalabo
# Processing Record 268: guarapari
# Processing Record 269: alice springs
# City not found. Skipping...
# Processing Record 271: goundam
# Processing Record 272: lompoc
# Processing Record 273: sao filipe
# Processing Record 274: vila franca do campo
# Processing Record 275: oranjemund
# Processing Record 276: chalus
# Processing Record 277: pakxan
# Processing Record 278: rawson
# Processing Record 279: nome
# Processing Record 280: caravelas
# City not found. Skipping...
# Processing Record 282: gunnedah
# Processing Record 283: juneau
# Processing Record 284: nago
# Processing Record 285: flin flon
# Processing Record 286: talnakh
# Processing Record 287: larsnes
# City not found. Skipping...
# Processing Record 289: mar del plata
# Processing Record 290: forest hill
# Processing Record 291: viedma
# Processing Record 292: mitsamiouli
# City not found. Skipping...
# Processing Record 294: marawi
# Processing Record 295: staryy nadym
# Processing Record 296: borovoy
# Processing Record 297: koumac
# Processing Record 298: ceccano
# Processing Record 299: namibe
# Processing Record 300: riviere-au-renard
# Processing Record 301: mahibadhoo
# City not found. Skipping...
# Processing Record 303: umm bab
# Processing Record 304: tacna
# Processing Record 305: pareora
# Processing Record 306: sovetskaya gavan
# Processing Record 307: porto novo
# Processing Record 308: laguna
# City not found. Skipping...
# Processing Record 310: hokitika
# Processing Record 311: tinaquillo
# Processing Record 312: berlevag
# Processing Record 313: port augusta
# Processing Record 314: harrisonburg
# Processing Record 315: bowen
# Processing Record 316: rudnyy
# Processing Record 317: pekan
# Processing Record 318: muros
# Processing Record 319: brae
# Processing Record 320: san policarpo
# Processing Record 321: ancud
# Processing Record 322: miraflores
# Processing Record 323: westport
# Processing Record 324: havelock
# Processing Record 325: muroto
# Processing Record 326: atar
# Processing Record 327: avera
# Processing Record 328: semey
# City not found. Skipping...
# Processing Record 330: noumea
# City not found. Skipping...
# Processing Record 332: hun
# City not found. Skipping...
# Processing Record 334: sistranda
# Processing Record 335: esperance
# Processing Record 336: dingle
# Processing Record 337: mehamn
# Processing Record 338: bayonet point
# Processing Record 339: fare
# Processing Record 340: lakes entrance
# Processing Record 341: okhotsk
# Processing Record 342: djambala
# Processing Record 343: san angelo
# Processing Record 344: ola
# Processing Record 345: preobrazheniye
# Processing Record 346: lorengau
# Processing Record 347: byron bay
# Processing Record 348: nhulunbuy
# Processing Record 349: zelenogorskiy
# Processing Record 350: loandjili
# Processing Record 351: cabedelo
# Processing Record 352: salinas
# Processing Record 353: fortuna
# Processing Record 354: riverton
# Processing Record 355: thompson
# Processing Record 356: chiguayante
# Processing Record 357: kalispell
# Processing Record 358: moose factory
# Processing Record 359: kununurra
# Processing Record 360: los llanos de aridane
# Processing Record 361: kavaratti
# Processing Record 362: kruisfontein
# Processing Record 363: manta
# Processing Record 364: manaure
# Processing Record 365: ocos
# Processing Record 366: asau
# Processing Record 367: aykhal
# Processing Record 368: santiago del estero
# Processing Record 369: yerbogachen
# Processing Record 370: taungdwingyi
# Processing Record 371: kota belud
# Processing Record 372: saint thomas
# Processing Record 373: torbay
# Processing Record 374: khani
# Processing Record 375: mantua
# Processing Record 376: katherine
# Processing Record 377: saint george
# Processing Record 378: pachino
# Processing Record 379: chandbali
# City not found. Skipping...
# Processing Record 381: mormugao
# City not found. Skipping...
# Processing Record 383: poya
# Processing Record 384: college
# Processing Record 385: bhag
# Processing Record 386: diamantino
# Processing Record 387: codrington
# Processing Record 388: quatre cocos
# Processing Record 389: makakilo city
# Processing Record 390: yellowknife
# Processing Record 391: hofn
# Processing Record 392: saint anthony
# Processing Record 393: whitehorse
# Processing Record 394: puri
# Processing Record 395: port blair
# Processing Record 396: guerrero negro
# Processing Record 397: sibut
# Processing Record 398: sao joao da barra
# City not found. Skipping...
# Processing Record 400: hulan ergi
# Processing Record 401: galle
# Processing Record 402: kipini
# Processing Record 403: kaitangata
# Processing Record 404: longyearbyen
# Processing Record 405: hambantota
# Processing Record 406: inhambane
# Processing Record 407: santa cruz de tenerife
# Processing Record 408: turukhansk
# Processing Record 409: kudahuvadhoo
# Processing Record 410: gibara
# Processing Record 411: nishihara
# Processing Record 412: yulara
# Processing Record 413: akdepe
# City not found. Skipping...
# Processing Record 415: haines junction
# Processing Record 416: santa maria
# Processing Record 417: batticaloa
# Processing Record 418: lata
# Processing Record 419: fallon
# Processing Record 420: warrington
# Processing Record 421: mangaldai
# Processing Record 422: ponta do sol
# Processing Record 423: raudeberg
# Processing Record 424: antalaha
# City not found. Skipping...
# Processing Record 426: krugersdorp
# Processing Record 427: vardo
# Processing Record 428: sao raimundo das mangabeiras
# Processing Record 429: ron phibun
# Processing Record 430: nalut
# Processing Record 431: leningradskiy
# Processing Record 432: ixtapa
# Processing Record 433: shingu
# Processing Record 434: paraopeba
# Processing Record 435: bone
# Processing Record 436: dunedin
# Processing Record 437: price
# Processing Record 438: oistins
# Processing Record 439: bilma
# Processing Record 440: nemuro
# Processing Record 441: seymchan
# Processing Record 442: loa janan
# Processing Record 443: abha
# Processing Record 444: deputatskiy
# City not found. Skipping...
# Processing Record 446: chara
# Processing Record 447: angoche
# Processing Record 448: severodvinsk
# Processing Record 449: clyde river
# Processing Record 450: henties bay
# Processing Record 451: carupano
# Processing Record 452: ambilobe
# Processing Record 453: port-gentil
# Processing Record 454: port hedland
# Processing Record 455: balakhta
# Processing Record 456: san juan
# City not found. Skipping...
# Processing Record 458: cabra
# City not found. Skipping...
# Processing Record 460: richards bay
# Processing Record 461: bairiki
# Processing Record 462: nuuk
# Processing Record 463: sao jose da coroa grande
# Processing Record 464: osecina
# Processing Record 465: acarau
# Processing Record 466: mayo
# City not found. Skipping...
# Processing Record 468: phan thiet
# Processing Record 469: chapais
# Processing Record 470: santa rosa
# Processing Record 471: yenagoa
# Processing Record 472: adrar
# Processing Record 473: jonesboro
# City not found. Skipping...
# Processing Record 475: castlegar
# Processing Record 476: high level
# Processing Record 477: tocopilla
# Processing Record 478: ivaipora
# Processing Record 479: mount pleasant
# Processing Record 480: porkhov
# City not found. Skipping...
# Processing Record 482: isangel
# Processing Record 483: benghazi
# Processing Record 484: totness
# Processing Record 485: gizo
# Processing Record 486: canakkale
# Processing Record 487: port lincoln
# Processing Record 488: ankpa
# Processing Record 489: bilibino
# Processing Record 490: luderitz
# Processing Record 491: barranco
# Processing Record 492: kahului
# Processing Record 493: ekhabi
# Processing Record 494: ketchikan
# Processing Record 495: iquique
# Processing Record 496: superior
# Processing Record 497: senneterre
# City not found. Skipping...
# Processing Record 499: tessalit
# Processing Record 500: chihuahua
# Processing Record 501: samarai
# Processing Record 502: coolum beach
# Processing Record 503: novoilinsk
# Processing Record 504: shelburne
# Processing Record 505: castanos
# Processing Record 506: lask
# Processing Record 507: hirara
# Processing Record 508: murupara
# Processing Record 509: paramonga
# City not found. Skipping...
# Processing Record 511: meulaboh
# Processing Record 512: tambura
# Processing Record 513: kholm
# Processing Record 514: beya
# Processing Record 515: petawawa
# Processing Record 516: port lavaca
# Processing Record 517: arvika
# Processing Record 518: mizdah
# Processing Record 519: aksha
# Processing Record 520: danville
# Processing Record 521: mortka
# City not found. Skipping...
# Processing Record 523: great falls
# Processing Record 524: ganzhou
# Processing Record 525: clonakilty
# Processing Record 526: tyrma
# Processing Record 527: lages
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 530: winnipeg
# Processing Record 531: san carlos de bariloche
# Processing Record 532: hay river
# City not found. Skipping...
# Processing Record 534: srednekolymsk
# Processing Record 535: kalianget
# Processing Record 536: ambulu
# Processing Record 537: palasa
# Processing Record 538: touros
# Processing Record 539: sorrento
# Processing Record 540: sechura
# Processing Record 541: maragogi
# Processing Record 542: garowe
# Processing Record 543: buin
# Processing Record 544: banda aceh
# Processing Record 545: ibaiti
# Processing Record 546: huallanca
# Processing Record 547: izumo
# Processing Record 548: tokur
# Processing Record 549: ambo
# Processing Record 550: ivanava
# Processing Record 551: megion
# Processing Record 552: kushima
# Processing Record 553: bang saphan
# Processing Record 554: gobabis
# City not found. Skipping...
# Processing Record 556: hamilton
# Processing Record 557: buta
# Processing Record 558: nanakuli
# Processing Record 559: ashqelon
# City not found. Skipping...
# Processing Record 561: provideniya
# Processing Record 562: fort nelson
# Processing Record 563: pilar
# Processing Record 564: melk
# Processing Record 565: malindi
# Processing Record 566: evensk
# Processing Record 567: bayir
# Processing Record 568: biloela
# Processing Record 569: christchurch
# Processing Record 570: abalak
# Processing Record 571: arkadak
# Processing Record 572: comodoro rivadavia
# Processing Record 573: san cristobal
# Processing Record 574: zhuanghe
# Processing Record 575: san antonio
# City not found. Skipping...
# Processing Record 577: constitucion
# City not found. Skipping...
# Processing Record 579: gornoye loo
# Processing Record 580: bacolod
# Processing Record 581: bossangoa
# Processing Record 582: saint-georges
# Processing Record 583: port moresby
# Processing Record 584: oussouye
# Processing Record 585: twin falls
# Processing Record 586: horadiz
# Processing Record 587: pavlodar
# Processing Record 588: kieta
# Processing Record 589: ewa beach
# Processing Record 590: udachnyy
# Processing Record 591: popondetta
# Processing Record 592: broome
# Processing Record 593: sola
# Processing Record 594: polyarnyy
# Processing Record 595: souillac
# Processing Record 596: shenkursk
# Processing Record 597: gorontalo
# Processing Record 598: sayyan
# Processing Record 599: pierreville
# Processing Record 600: zhezkazgan
# Processing Record 601: taltal
# Processing Record 602: sungairaya
# Processing Record 603: bonthe
# Processing Record 604: bathsheba
# Processing Record 605: kindu
# Processing Record 606: vao
# Processing Record 607: tamandare
# Processing Record 608: svetlogorsk
# Processing Record 609: sorland
# Processing Record 610: itinga
# Processing Record 611: zinder
# City not found. Skipping...
# Processing Record 613: kangaatsiaq
# Processing Record 614: itaqui
# Processing Record 615: pinheiro machado
# Processing Record 616: belaya gora
# Processing Record 617: luanda
# Processing Record 618: debica
# City not found. Skipping...
# Processing Record 620: velyka oleksandrivka
# Processing Record 621: cervo
# Processing Record 622: namatanai
# Processing Record 623: talpa
# Processing Record 624: zhangjiakou
# Processing Record 625: shache
# Processing Record 626: cardinal
# Processing Record 627: high prairie
# Processing Record 628: morrinhos
# Processing Record 629: tilichiki
# Processing Record 630: yasothon
# Processing Record 631: sao paulo de olivenca
# Processing Record 632: baykit
# Processing Record 633: qui nhon
# Processing Record 634: cambridge
# Processing Record 635: bubaque
# Processing Record 636: ponta delgada
# City not found. Skipping...
# Processing Record 638: tsumeb
# Processing Record 639: muzhi
# Processing Record 640: taldan
# Processing Record 641: rocha

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.to_csv("weather_df.csv")

weather_df.count()
# Out:
# City                585
# Cloudiness (%)      585
# Country             585
# Date                585
# Humidity (%)        585
# Latitude            585
# Longitude           585
# Max Temp (F)        585
# Wind Speed (mph)    585
# dtype: int64

# %%
weather_df.head(10)
# Out:
#             City  Cloudiness (%) Country        Date  Humidity (%)  Latitude  \
# 0      Hithadhoo             100      MV  1601525498            72     -0.60
# 1    San Quintín               0      MX  1601525501            38     30.48
# 2      Palāsbāri              75      IN  1601525502           100     26.14
# 3         Hobart              72      AU  1601525375            30    -42.88
# 4            Soe              70      ID  1601525506            34     -9.86
# 5  Krasnosel'kup             100      RU  1601525508            78     65.70
# 6          Zunyi             100      CN  1601525509            93     27.69
# 7        Mataura              92      NZ  1601525512            58    -46.19
# 8        Rikitea              83      PF  1601525514            82    -23.12
# 9        Canguçu              71      BR  1601525373            91    -31.39
#
#    Longitude  Max Temp (F)  Wind Speed (mph)
# 0      73.08         82.78              3.74
# 1    -115.95         80.28              5.70
# 2      91.55         89.60              3.58
# 3     147.33         60.01             18.34
# 4     124.28         87.57             13.94
# 5      82.47         37.85              7.52
# 6     106.91         61.50              3.65
# 7     168.86         56.21              5.23
# 8    -134.97         72.45             24.96
# 9     -52.68         69.01              3.00

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="lightblue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
plt.grid()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="lightblue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="lightblue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
plt.grid()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="lightblue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
plt.grid()

# %% [markdown]
# ## Linear Regression

# %%
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.grid()
# Out:
# Regression line equation is: y = -0.77x + 91.27

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.69x + 83.76
# The r-squared is: 0.6714662271889353

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.14x + 67.45
# The r-squared is: 0.13941052717607563

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.19x + 73.8
# The r-squared is: 0.13039034889143103

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(4,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.24x + 42.58
# The r-squared is: 0.12088840337003749

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.28x + 53.3
# The r-squared is: 0.09766838387111346

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = 0.03x + 6.48
# The r-squared is: 0.1097488838207469

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.grid()
# Out:
# Regression line equation is: y = -0.09x + 7.3
# The r-squared is: -0.1874350628395226

# %%
Observable trends based on the data

1. When comparing Northern Hemisphere & Southern Hemisphere "Wind Speed vs. Latitude Linear Regression", Northern Hemispher has an upward trajectory compared to Southern Hemisphere.
2. In Southern Hemisphere, the graph shows no correlation between Cloudiness vs. Latitude Linear Regression.
3. Southern Hemisphere has a positive trajectory on Max Temp compared to Northern Hemisphere.
